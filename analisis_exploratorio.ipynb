# %% [markdown]
# <a href="https://colab.research.google.com/github/iair/financial_health/blob/main/analisis_exploratorio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# prompt: importa las librerias pandas, numbpy, matplotlib, seaborn, os, request, json

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import requests
import json

# %%
url = "https://api.floid.app/cl/banco_itau_personas/products"

payload = {
    "id": rut,
    "password": password,
    "unlock_credentials": False
}
headers = {
    "accept": "application/json",
    "content-type": "application/json",
    "authorization": token
}

response = requests.post(url, json=payload, headers=headers)

print(response.text)
# Out:
# {"code":"200","msg":"OK","caseid":"8b9a7527-d466-468c-8289-0e510e5d284c","products":{"accounts":[{"type":"corriente","number":223635815,"currency":"CLP","balance":4687}],"cards":[{"number":"**6012","type":"credito","name":"Mastercard Black Pb","CLP":{"total":7000000,"used":5990805,"available":1009195},"USD":{"total":875833,"used":2563,"available":87327}}],"lines":[{"number":223635825,"CLP":{"total":1000000,"used":0,"available":1000000}}]}}

# %%
response_dict = json.loads(response.text)
response_dict.keys()
# Out:
# dict_keys(['code', 'msg', 'caseid', 'products'])

# %%
account_number = response_dict.get('products').get('accounts')[0].get('number')

# %%
url = "https://api.floid.app/cl/banco_itau_personas/transactions"

payload = {
    "id": rut,
    "password": password,
    "account_number": account_number,
    "history": True
}

response = requests.post(url, json=payload, headers=headers)

print(response.text)
# Out:
# {"code":"200","msg":"Ok","caseid":"2b9edaae-9957-42f3-9b96-14eecc36eda5","transactions":[{"date":"2024-01-02","branch":null,"description":"Transferencia A Daniela Silva","doc_number":"333735497","out":8096,"in":0,"balance":3490188,"id":"2891b1654ddbf44fb75bea431c57ee161"},{"date":"2024-01-02","branch":null,"description":"Transferencia A Paulina Oreall","doc_number":"333896469","out":3000,"in":0,"balance":3487188,"id":"d98e1821aea3249c129a660fcf37bca01"},{"date":"2024-01-04","branch":null,"description":"Transferencia A Spot Vista Los","doc_number":"334778753","out":1285880,"in":0,"balance":2201308,"id":"930984c1728026fe8a84a1cb64dcf6451"},{"date":"2024-01-05","branch":null,"description":"Transferencia A Floid Spa","doc_number":"334849615","out":191473,"in":0,"balance":2009835,"id":"82abce1fa9b42ae01258d02bdb1e12dd1"},{"date":"2024-01-05","branch":null,"description":"Transferencia A Germanie","doc_number":"334893597","out":120000,"in":0,"balance":1889835,"id":"100ea58aa1bb08fb1b7e38033771b28d1"},{"date":"2024-01-05","branch":null,"description":"Transferencia De Andes Str Spa","doc_number":"334958957","out":0,"in":846155,"balance":2735990,"id":"22e0187f3bca9855755f8fea893f55381"},{"date":"2024-01-05","branch":null,"description":"Transferencia A Asrdorias Bvr","doc_number":"335089520","out":70000,"in":0,"balance":2665990,"id":"232740e2f9290d2ebb798fbda9ef4da31"},{"date":"2024-01-08","branch":null,"description":"Liquid Intereses Pactados","doc_number":"000000000","out":880,"in":0,"balance":2665110,"id":"afe78b98005a21430c0b282238d590091"},{"date":"2024-01-08","branch":null,"description":"Imp\/sobreg. Lc","doc_number":"000000000","out":68,"in":0,"balance":2665042,"id":"0c6d626a575a6f80d8454d8c65a005781"},{"date":"2024-01-09","branch":null,"description":"Pago Servipag","doc_number":"000000000","out":81527,"in":0,"balance":658473,"id":"3a7bab9abe47ad2212b577d3b3f3f7c11"},{"date":"2024-01-09","branch":null,"description":"Transferencia A Iair Linker","doc_number":"336035219","out":1115673,"in":0,"balance":740000,"id":"5879f204d6b7ae3ef7b11db1431d97811"},{"date":"2024-01-09","branch":null,"description":"Transferencia De Iair Moises L","doc_number":"336033009","out":0,"in":1386357,"balance":4051399,"id":"4c4b290f6e7570e2990fa1793dee760f1"},{"date":"2024-01-09","branch":null,"description":"Pago Tarjeta De Credito","doc_number":"000000000","out":2195726,"in":0,"balance":1855673,"id":"2b6cbcdd804a5e6215b1bd2a2c7f65611"},{"date":"2024-01-10","branch":null,"description":"Pago Servipag","doc_number":"000000000","out":8435,"in":0,"balance":650038,"id":"88de45187c08d336cae14f70db2495a61"},{"date":"2024-01-10","branch":null,"description":"Transferencia A Edificio Estor","doc_number":"336134201","out":193582,"in":0,"balance":456456,"id":"2dc44815f313b41bda63f5c140c9470e1"},{"date":"2024-01-10","branch":null,"description":"Transferencia A Jean Paul","doc_number":"336181977","out":24000,"in":0,"balance":432456,"id":"8307979e4e6ebcfa7802e70cd8cdb7581"},{"date":"2024-01-10","branch":null,"description":"Pago Automat. Tarjeta Credito","doc_number":"000000000","out":102128,"in":0,"balance":330328,"id":"56768534d93c7536d32d8e8fb49eca9b1"},{"date":"2024-01-11","branch":null,"description":"Transferencia De Andes Str Spa","doc_number":"336400447","out":0,"in":78819,"balance":1246551,"id":"11954bf4c207e868e1af7117b9e94cfa1"},{"date":"2024-01-11","branch":null,"description":"Transferencia A Carolina Duque","doc_number":"336452205","out":134410,"in":0,"balance":145076,"id":"a124825c750274c393aed95b3ef0ad091"},{"date":"2024-01-11","branch":null,"description":"Transferencia A Clara San Juan","doc_number":"336403156","out":1200000,"in":0,"balance":279486,"id":"fab10edc6b3f732e8c3fcd48aa61adf11"},{"date":"2024-01-11","branch":null,"description":"Transferencia De Andes Str Spa","doc_number":"336400461","out":0,"in":37353,"balance":1479486,"id":"a802ef90b514ba744c7b11cea08efe951"},{"date":"2024-01-11","branch":null,"description":"Transferencia De Andes Str Spa","doc_n ...

# %%
response_dict = json.loads(response.text)
response_dict.keys()
# Out:
# dict_keys(['code', 'msg', 'caseid', 'transactions'])

# %%
transactions = response_dict.get('transactions')
type(transactions)
# Out:
# list

# %%
print(len(transactions))
transactions[0]
# Out:
# 57
# {'date': '2024-01-02',
#  'branch': None,
#  'description': 'Transferencia A Daniela Silva',
#  'doc_number': '333735497',
#  'out': 8096,
#  'in': 0,
#  'balance': 3490188,
#  'id': '2891b1654ddbf44fb75bea431c57ee161'}

# %%
# prompt: genera un dataframe con todas las transacciones en transactions
df = pd.DataFrame(transactions)
df.head()
# Out:
#          date branch                     description doc_number      out  in  \
# 0  2024-01-02   None   Transferencia A Daniela Silva  333735497     8096   0
# 1  2024-01-02   None  Transferencia A Paulina Oreall  333896469     3000   0
# 2  2024-01-04   None  Transferencia A Spot Vista Los  334778753  1285880   0
# 3  2024-01-05   None       Transferencia A Floid Spa  334849615   191473   0
# 4  2024-01-05   None        Transferencia A Germanie  334893597   120000   0
#
#    balance                                 id
# 0  3490188  2891b1654ddbf44fb75bea431c57ee161
# 1  3487188  d98e1821aea3249c129a660fcf37bca01
# 2  2201308  930984c1728026fe8a84a1cb64dcf6451
# 3  2009835  82abce1fa9b42ae01258d02bdb1e12dd1
# 4  1889835  100ea58aa1bb08fb1b7e38033771b28d1

# %%
print(min(df.date))
max(df.date)
# Out:
# 2024-01-02
# '2024-02-20'

# %%
# prompt: crea un gráfico que me muestre los egresos (usando la columna out) vs los ingresos (usando la columna in) a lo largo del tiempo con granularidad semanal y otro mensual

df['date'] = pd.to_datetime(df['date'])
df['week'] = df['date'].dt.week
df['month'] = df['date'].dt.month

# Create a pivot table for weekly data
weekly_pivot = df.pivot_table(values=['in', 'out'], index='week', aggfunc=sum)

# Create a line plot for weekly data
plt.figure(figsize=(12, 6))
sns.lineplot(data=weekly_pivot)
plt.title('Weekly Incomes and Expenses')
plt.xlabel('Week')
plt.ylabel('Amount')
plt.show()

# Create a pivot table for monthly data
monthly_pivot = df.pivot_table(values=['in', 'out'], index='month', aggfunc=sum)

# Create a line plot for monthly data
plt.figure(figsize=(12, 6))
sns.lineplot(data=monthly_pivot)
plt.title('Monthly Incomes and Expenses')
plt.xlabel('Month')
plt.ylabel('Amount')
plt.show()
# Out:
# <ipython-input-48-add93963112f>:4: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated. Please use Series.dt.isocalendar().week instead.
#   df['week'] = df['date'].dt.week

# %%
# prompt: crea dos gráfico que me muestre los egresos (usando la columna out) vs los ingresos (usando la columna in) a lo largo del tiempo usando la variable date para el tiempo. Usa unidades de mil  para el eje Y y que el eje se llame "CLP en miles"

import matplotlib.pyplot as plt
# Create a new column for CLP in thousands
df['clp_thousands'] = df['out'] / 1000

# Create a line plot for daily data
plt.figure(figsize=(12, 6))
sns.lineplot(data=df, x='date', y='clp_thousands')
plt.title('Daily Expenses vs. Income (CLP in thousands)')
plt.xlabel('Date')
plt.ylabel('CLP in thousands')
plt.show()

# Create a pivot table for weekly data
weekly_pivot = df.pivot_table(values=['in', 'out'], index='week', aggfunc=sum)

# Create a new column for CLP in thousands
weekly_pivot['clp_thousands'] = weekly_pivot['out'] / 1000

# Create a line plot for weekly data
plt.figure(figsize=(12, 6))
sns.lineplot(data=weekly_pivot, x='week', y='clp_thousands')
plt.title('Weekly Expenses vs. Income (CLP in thousands)')
plt.xlabel('Week')
plt.ylabel('CLP in thousands')
plt.show()

# %%
# prompt: # prompt: crea un gráfico de linea que me muestre el resultado neto de restar los egresos (usando la columna out en unidades de miles) vs los ingresos (usando la columna in en unidades de miles) a lo largo del tiempo usando la variable date para el tiempo con granularidad semanal. Que aparezcan las etiquetas al centro . La leyenda debe estar arriba redondeada

import matplotlib.pyplot as plt
df['clp_thousands_in'] = df['in'] / 1000
df['clp_thousands_out'] = df['out'] / 1000

# Create a new dataframe with the desired columns
df_net = df[['date', 'clp_thousands_in', 'clp_thousands_out']]

# Calculate the net income for each week
df_net['net_income'] = df_net['clp_thousands_in'] - df_net['clp_thousands_out']

# Create a line plot for weekly data
plt.figure(figsize=(12, 6))
sns.lineplot(data=df_net, x='date', y='net_income')
plt.title('Weekly Net Income (CLP in thousands)')
plt.xlabel('Date')
plt.ylabel('CLP in thousands')

# Annotate the plot with labels
for i, row in df_net.iterrows():
    plt.annotate(str(row['net_income']), (i, row['net_income']), ha='center', va='center')

# Add legend and adjust its position
plt.legend(bbox_to_anchor=(0.5, 1.05), loc='upper center', ncol=1)

# Show the plot
plt.show()
# Out:
# <ipython-input-85-1d2760748d32>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_net['net_income'] = df_net['clp_thousands_in'] - df_net['clp_thousands_out']
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
# prompt: # prompt: crea un gráfico de barras comparado que me muestre el la diferencia entre los egresos (usando la columna out en unidades de miles) vs los ingresos (usando la columna in en unidades de miles) a lo largo del tiempo usando la variable date para el tiempo con granularidad de meses. Que aparezcan las etiquetas al centro . La leyenda debe estar arriba redondeada

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Create a new column for CLP in thousands
df['clp_thousands_in'] = df['in'] / 1000
df['clp_thousands_out'] = df['out'] / 1000

# Create a pivot table for monthly data
monthly_pivot = df.pivot_table(values=['clp_thousands_in', 'clp_thousands_out'], index='month', aggfunc=sum)

# Create a bar chart
fig, ax = plt.subplots(figsize=(12, 6))

monthly_pivot.plot(kind='bar', ax=ax, title='Monthly Income vs. Expenses (CLP in Thousands)', legend=False)

# Add labels to each bar
for i, bar in enumerate(ax.patches):
    ax.text(bar.get_x() + bar.get_width() / 2, bar.get_height(),
            str(round(bar.get_height(), 1)), ha='center', va='bottom')

# Add legend
ax.legend(loc='upper center', bbox_to_anchor=(0.5, 1.15), ncol=2, fancybox=True, shadow=True)

# Show the plot
plt.show()

# %%
# prompt: crea un gráfico de linea que me muestre el resultado neto acumulado de restar los egresos (usando la columna out en unidades de miles) vs los ingresos (usando la columna in en unidades de miles) a lo largo del tiempo usando la variable date para el tiempo con granularidad semanal. Que aparezcan las etiquetas al centro . La leyenda debe estar arriba redondeada

import matplotlib.pyplot as plt
# Calculate the cumulative sum of net income
df_net['net_income_cumulative'] = df_net['net_income'].cumsum()

# Create a line plot for weekly data
plt.figure(figsize=(12, 6))
sns.lineplot(data=df_net, x='date', y='net_income_cumulative')
plt.title('Cumulative Net Income (CLP in Thousands)')
plt.xlabel('Date')
plt.ylabel('CLP in thousands')

# Annotate the plot with labels
for i, row in df_net.iterrows():
    plt.annotate(str(row['net_income_cumulative']), (i, row['net_income_cumulative']), ha='center', va='center')

# Add legend and adjust its position
plt.legend(bbox_to_anchor=(0.5, 1.05), loc='upper center', ncol=1, fancybox=True, shadow=True)

# Show the plot
plt.show()
# Out:
# <ipython-input-86-b5533527af3b>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_net['net_income_cumulative'] = df_net['net_income'].cumsum()
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
# prompt: agrupa las transacciones de egresos (usando la variable out)  por su descripción única (usando la variable description) y muéstrame las top 10 en frecuencia para cada mes en un gráfico de barras horizonal

import matplotlib.pyplot as plt
import pandas as pd

# Agrupar las transacciones por mes y descripción
grouped_df = df[df['out'] > 0].groupby(['month', 'description']).size().reset_index(name='count')

# Obtener las top 10 descripciones más frecuentes para cada mes
top_10_df = grouped_df.groupby('month').apply(lambda x: x.nlargest(10, 'count'))

# Crear un gráfico de barras horizontales para cada mes
for month in top_10_df.month.unique():
    month_df = top_10_df[top_10_df['month'] == month]
    plt.figure(figsize=(12, 6))
    sns.barplot(x='count', y='description', data=month_df)
    plt.title(f'Top 10 gastos más frecuentes en {month_df.month.iloc[0]}')
    plt.xlabel('Frecuencia')
    plt.ylabel('Descripción')
    plt.show()

# %%
# prompt: agrupa las transacciones de egresos (usando la variable out)  por su descripción única (usando la variable description) y muéstrame las top 10 en monto para cada mes en un gráfico de barras horizonal

import matplotlib.pyplot as plt
monthly_grouped = df.groupby(['month', 'description'])['out'].sum().reset_index()
monthly_top_10 = monthly_grouped.groupby('month').apply(lambda x: x.nlargest(10, 'out')).reset_index(drop=True)

plt.figure(figsize=(12, 6))
sns.barplot(x='out', y='description', hue='month', data=monthly_top_10, orient='h')
plt.title('Top 10 Monthly Expenses by Description (CLP)')
plt.xlabel('Total Expense (CLP)')
plt.ylabel('Expense Description')
plt.legend(title='Month')
plt.tight_layout()
plt.show()

# %%
# prompt: agrupa las transacciones de egresos (usando la variable out)  por su descripción única (usando la variable description) y de todas las transacciones menores a 50.000 y mayores a 0 pesos chilenos en monto, muéstrame las top 20 por monto de mayor a menor para cada mes en un gráfico de barras horizonal

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Filter transactions between 0 and 50,000 CLP
filtered_df = df[(df['out'] > 0) & (df['out'] < 50000)]

# Group transactions by month and description, and sum the out amounts
grouped_df = filtered_df.groupby(['month', 'description'])['out'].sum().reset_index()

# Get the top 20 transactions for each month
top_20_df = grouped_df.groupby('month').apply(lambda x: x.nlargest(20, 'out')).reset_index(drop=True)

# Create a horizontal bar chart for each month
for month in top_20_df.month.unique():
    month_df = top_20_df[top_20_df['month'] == month]
    plt.figure(figsize=(12, 6))
    sns.barplot(x='out', y='description', data=month_df)
    plt.title(f'Top 20 Monthly Expenses by Description (CLP) - {month}')
    plt.xlabel('Total Expense (CLP)')
    plt.ylabel('Expense Description')
    plt.tight_layout()
    plt.show()

# %%
# prompt: muéstrame una tabla con la frecuencia y monto de las transacciones (usa out), agrupando con la descripción de las transacciones (usa description como variable)

import pandas as pd

# Filter transactions between 0 and 50,000 CLP
filtered_df = df[(df['out'] > 0) & (df['out'] < 50000)]

# Group transactions by description and calculate frequency and total amount
grouped_df = filtered_df.groupby('description').agg(
    frequency=pd.NamedAgg(column='out', aggfunc='count'),
    total_amount=pd.NamedAgg(column='out', aggfunc='sum')
)

# Sort by frequency and reset index
grouped_df.sort_values(by='frequency', ascending=False, inplace=True)
grouped_df.reset_index(inplace=True)

# Print the table
print(grouped_df.to_string())
# Out:
#                       description  frequency  total_amount
# 0           Pac Seg.cardif 110280          2         16202
# 1  Transferencia A Paulina Oreall          2          6500
# 2                  Imp/sobreg. Lc          1            68
# 3       Liquid Intereses Pactados          1           880
# 4                   Pago Servipag          1          8435
# 5    Transf. A Iair Moises Linker          1         32313
# 6   Transferencia A Daniela Silva          1          8096
# 7    Transferencia A Edificio Est          1          5490
# 8  Transferencia A Edificio Estor          1         22383
# 9       Transferencia A Jean Paul          1         24000

# %%
# prompt: muéstrame una tabla con la frecuencia y monto de las transacciones (usa in), agrupando con la descripción de las transacciones (usa description como variable)

import pandas as pd
# Filter transactions with positive inflow
filtered_df = df[df['in'] > 0]

# Group transactions by description and calculate frequency and total amount
grouped_df = filtered_df.groupby('description').agg(
    frequency=pd.NamedAgg(column='in', aggfunc='count'),
    total_amount=pd.NamedAgg(column='in', aggfunc='sum')
)

# Sort by frequency and reset index
grouped_df.sort_values(by='frequency', ascending=False, inplace=True)
grouped_df.reset_index(inplace=True)

# Print the table
print(grouped_df.to_string())
# Out:
#                        description  frequency  total_amount
# 0   Transferencia De Andes Str Spa          9       2017696
# 1     Pago Proveedor    76263414-7          2         58930
# 2     Abono Desde Linea De Credito          1         32313
# 3            Pago Dap Web  0397841          1        714303
# 4            Pago Dap Web  1308400          1       1156194
# 5                  Pago De Sueldos          1       3445641
# 6                     Pagos Varios          1       1400509
# 7     Transferencia De Alvaro Este          1         37000
# 8     Transferencia De Andes Str S          1        844177
# 9   Transferencia De Constanza Dia          1         18200
# 10  Transferencia De Iair Moises L          1       1386357
